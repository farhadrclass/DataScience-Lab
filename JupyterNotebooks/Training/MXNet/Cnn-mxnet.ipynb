# %% [markdown]
# # Traffic sign classification using a convolutional neural network in MXNet

# %% [markdown]
# TODO: Add link to blog article when it's ready.
# 1. In this notebook we are going to classify German traffic signs using a convolutional neural network
# 2. We will learn about implementing convolution using MXNet.
# 3. The notebook assumes that you have a broad understanding of convolutional neural networks.

# %%
#some imports along with mxnet
# %matplotlib inline
import mxnet as mx
import numpy as np 
import cv2
import matplotlib.pyplot as plt
import logging

logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %%
# Load pickled data
# we already have all the data pickled to file. This helps easy loading of train and validation set
import pickle

# TODO: The train and validation data should be stored inside the folder traffic-data

training_file = "/usr/local/share/dsLab/datasets/traffic-data/train.p"
validation_file =  "/usr/local/share/dsLab/datasets/traffic-data/valid.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)

with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']

# %% [markdown]
# We are going to print few statistics to get a sense of what our data looks like. Labelling German traffic signs is a multi-class classification problem. There are, we'll see, 43 different classes of traffic sign in the dataset.
#
# ### Statistics about the data

# %%
# Number of training examples
n_train = len(X_train)

#Number of testing examples.
n_test = len(X_valid)

# What's the shape of an traffic sign image?
image_shape = X_train[0].shape

# How many unique classes/labels there are in the dataset.
n_classes = len(np.unique(y_train))

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
print(y_train.shape)
# Out:
# Number of training examples = 34799
# Number of testing examples = 4410
# Image data shape = (32, 32, 3)
# Number of classes = 43
# (34799,)

# %%
#Record the image size, number of channels (RGB) and classes
img_size = X_train[0].shape[0]
num_channels = X_train[0].shape[2]
num_classes = n_classes

# %% [markdown]
# The actual names of the classes are given in separate csv file. We need to load the csv file to map label id's to the natural language category names.

# %%
# The actual name of the classes are given in separate file. Here we load the csv file which allows mapping from classes/labels to 
# file name
import csv
def read_csv_and_parse():
    traffic_labels_dict ={}
    with open('/usr/local/share/dsLab/datasets/traffic-data/signnames.csv') as f:
        reader = csv.reader(f)
        count = -1;
        for row in reader:
            count = count + 1
            if(count == 0):
                continue
            label_index = int(row[0])
            traffic_labels_dict[label_index] = row[1]
    return traffic_labels_dict
traffic_labels_dict = read_csv_and_parse()
print(traffic_labels_dict)
# Out:
# {0: 'Speed limit (20km/h)', 1: 'Speed limit (30km/h)', 2: 'Speed limit (50km/h)', 3: 'Speed limit (60km/h)', 4: 'Speed limit (70km/h)', 5: 'Speed limit (80km/h)', 6: 'End of speed limit (80km/h)', 7: 'Speed limit (100km/h)', 8: 'Speed limit (120km/h)', 9: 'No passing', 10: 'No passing for vehicles over 3.5 metric tons', 11: 'Right-of-way at the next intersection', 12: 'Priority road', 13: 'Yield', 14: 'Stop', 15: 'No vehicles', 16: 'Vehicles over 3.5 metric tons prohibited', 17: 'No entry', 18: 'General caution', 19: 'Dangerous curve to the left', 20: 'Dangerous curve to the right', 21: 'Double curve', 22: 'Bumpy road', 23: 'Slippery road', 24: 'Road narrows on the right', 25: 'Road work', 26: 'Traffic signals', 27: 'Pedestrians', 28: 'Children crossing', 29: 'Bicycles crossing', 30: 'Beware of ice/snow', 31: 'Wild animals crossing', 32: 'End of all speed and passing limits', 33: 'Turn right ahead', 34: 'Turn left ahead', 35: 'Ahead only', 36: 'Go straight or right', 37: 'Go straight or left', 38: 'Keep right', 39: 'Keep left', 40: 'Roundabout mandatory', 41: 'End of no passing', 42: 'End of no passing by vehicles over 3.5 metric tons'}

# %% [markdown]
# ### Next, we will visualise the data and see the corresponding image and traffic sign labels

# %%
# Data exploration visualization
# This gives better understanding of the data

import matplotlib.pyplot as plt
from matplotlib.figure import Figure
# Visualizations will be shown in the notebook.
# %matplotlib inline

#This functions selects one image per class to plot
def get_images_to_plot(images, labels):
    selected_image = []
    idx = []
    for i in range(n_classes):
        selected = np.where(labels == i)[0][0]
        selected_image.append(images[selected])
        idx.append(selected)
    return selected_image,idx
 
# function to plot the images in a grid    
def plot_images(selected_image,y_val,row=15,col=3,idx = None):     
    count =0;
    f, axarr = plt.subplots(row, col,figsize=(48, 48))
   
    for i in range(row): 
         for j in range(col):
                if(count < len(selected_image)):
                    axarr[i,j].imshow(selected_image[count])
                    if(idx != None):
                        axarr[i,j].set_title(traffic_labels_dict[y_val[idx[count]]], fontsize=24)
                axarr[i,j].axis('off')
                count = count + 1

# %%
selected_image,idx = get_images_to_plot(X_valid,y_valid)
plot_images(selected_image,row=11,col=4,idx=idx,y_val=y_valid)

# %%
plt.imshow(X_train[28])

# %%
#change the image dimensioning from 32 X 32 X 3 to 3 X 32 X 32 for train

X_train_reshape = np.transpose(X_train, (0, 3, 1, 2))
plt.imshow(X_train_reshape[0].transpose((1,2,0)))
print(X_train_reshape.shape)
# Out:
# (34799, 3, 32, 32)

# %%
#change the image dimensioning from 32 X 32 X 3 to 3 X 32 X 32 for validation
X_valid_reshape = np.transpose(X_valid, (0, 3, 1, 2))
plt.imshow(X_valid_reshape[1].transpose((1,2,0)))
print(X_valid_reshape.shape)
# Out:
# (4410, 3, 32, 32)

# %% [markdown]
# ### Building the deepnet

# %% [markdown]
# Now, enough of preparing our dataset. Let's actually code the neural network up. You'll note that there are some commented-out lines; I've left these in as artifacts from the development process—building a successful deep learning model is all about iteration and experimentation to find what works best.
# The neural code is actually small and simple, thanks to MXNet symbol API:

# %%
data = mx.symbol.Variable('data')
conv1 = mx.sym.Convolution(data=data, pad=(1,1), kernel=(3,3), num_filter=24, name="conv1")
relu1 = mx.sym.Activation(data=conv1, act_type="relu", name= "relu1")
pool1 = mx.sym.Pooling(data=relu1, pool_type="max", kernel=(2,2), stride=(2,2),name="max_pool1")
# second conv layer
conv2 = mx.sym.Convolution(data=pool1, kernel=(3,3), num_filter=48, name="conv2", pad=(1,1))
relu2 = mx.sym.Activation(data=conv2, act_type="relu", name="relu2")
pool2 = mx.sym.Pooling(data=relu2, pool_type="max", kernel=(2,2), stride=(2,2),name="max_pool2")

conv3 = mx.sym.Convolution(data=pool2, kernel=(5,5), num_filter=64, name="conv3")
relu3 = mx.sym.Activation(data=conv3, act_type="relu", name="relu3")
pool3 = mx.sym.Pooling(data=relu3, pool_type="max", kernel=(2,2), stride=(2,2),name="max_pool3")

#conv4 = mx.sym.Convolution(data=conv3, kernel=(5,5), num_filter=64, name="conv3")
#relu4 = mx.sym.Activation(data=conv4, act_type="relu", name="relu3")
#pool4 = mx.sym.Pooling(data=relu4, pool_type="max", kernel=(2,2), stride=(2,2),name="max_pool3")

# first fullc layer
flatten = mx.sym.Flatten(data=pool3)
fc1 = mx.symbol.FullyConnected(data=flatten, num_hidden=500, name="fc1")
relu3 = mx.sym.Activation(data=fc1, act_type="relu" , name="relu3")
# second fullc
fc2 = mx.sym.FullyConnected(data=relu3, num_hidden=43,name="final_fc")
# softmax loss
mynet = mx.sym.SoftmaxOutput(data=fc2, name='softmax')

# %%
mynet.list_arguments()
# Out:
# ['data',
#  'conv1_weight',
#  'conv1_bias',
#  'conv2_weight',
#  'conv2_bias',
#  'conv3_weight',
#  'conv3_bias',
#  'fc1_weight',
#  'fc1_bias',
#  'final_fc_weight',
#  'final_fc_bias',
#  'softmax_label']

# %%
batch_size = 64
X_train_set_as_float = X_train_reshape.astype('float32')
#Noramilsing the image pixel to value between 0 to 1.0
X_train_set_norm = X_train_set_as_float[:] / 255.0;

#Noramilsing the image pixel to value between 0 to 1.0
X_validation_set_as_float = X_valid_reshape.astype('float32')
X_validation_set_norm = X_validation_set_as_float[:] / 255.0 ;


train_iter =mx.io.NDArrayIter(X_train_set_as_float, y_train, batch_size, shuffle=True)
val_iter = mx.io.NDArrayIter(X_validation_set_as_float, y_valid, batch_size,shuffle=True)


print("train set : ", X_train_set_norm.shape)
print("validation set : ", X_validation_set_norm.shape)


print("y train set : ", y_train.shape)
print("y validation set :", y_valid.shape)
# Out:
# train set :  (34799, 3, 32, 32)
# validation set :  (4410, 3, 32, 32)
# y train set :  (34799,)
# y validation set : (4410,)

# %% [markdown]
# ### Training the deepnet

# %% [markdown]
# We will use adam optimizer to optimize the weights of our deep neural network.

# %%
import logging
logging.getLogger().setLevel(logging.DEBUG)  # logging to stdout

#Create Adam optimiser
adam = mx.optimizer.create('adam')

#Checkpointing (saving the model). Make sure there is folder named models exist
model_prefix = 'cnn-mxnet-chkpt'
checkpoint = mx.callback.do_checkpoint(model_prefix)
                                       
#Loading the module API. Previously mxnet used feedforward (deprecated)                                       
model =  mx.mod.Module(
    symbol = mynet,
#    context = mx.gpu(0),     # use GPU 0 for training; if you don't have a gpu use mx.cpu()
    context = mx.cpu(),     # use GPU 0 for training; if you don't have a gpu use mx.cpu()
    data_names=['data']
   )
                                       
#actually fit the model for 10 epochs. Can take 5 minutes                                      
model.fit(
    train_iter,
    eval_data=val_iter, 
#    optimizer = 'sgd',
    optimizer = adam,
#    optimizer_params={'learning_rate':0.1},  # use fixed learning rate
    eval_metric='acc',
    batch_end_callback = mx.callback.Speedometer(batch_size, 64),
    num_epoch = 10,
    epoch_end_callback=checkpoint
)
# Out:
# /usr/local/share/dsLab/mxnet/python/mxnet/module/base_module.py:449: UserWarning: Optimizer created manually outside Module but rescale_grad is not normalized to 1.0/batch_size/num_workers (1.0 vs. 0.015625). Is this intended?
#   optimizer_params=optimizer_params)
# INFO:root:Epoch[0] Batch [64]	Speed: 432.17 samples/sec	accuracy=0.048077
# INFO:root:Epoch[0] Batch [128]	Speed: 431.69 samples/sec	accuracy=0.055176
# INFO:root:Epoch[0] Batch [192]	Speed: 433.79 samples/sec	accuracy=0.130127
# INFO:root:Epoch[0] Batch [256]	Speed: 408.83 samples/sec	accuracy=0.303467
# INFO:root:Epoch[0] Batch [320]	Speed: 435.02 samples/sec	accuracy=0.447021
# INFO:root:Epoch[0] Batch [384]	Speed: 430.55 samples/sec	accuracy=0.589111
# INFO:root:Epoch[0] Batch [448]	Speed: 428.37 samples/sec	accuracy=0.707520
# INFO:root:Epoch[0] Batch [512]	Speed: 430.24 samples/sec	accuracy=0.774902
# INFO:root:Epoch[0] Train-accuracy=0.823085
# INFO:root:Epoch[0] Time cost=81.145
# INFO:root:Saved checkpoint to "cnn-mxnet-chkpt-0001.params"
# INFO:root:Epoch[0] Validation-accuracy=0.746377
# INFO:root:Epoch[1] Batch [64]	Speed: 427.46 samples/sec	accuracy=0.840625
# INFO:root:Epoch[1] Batch [128]	Speed: 402.93 samples/sec	accuracy=0.871094
# INFO:root:Epoch[1] Batch [192]	Speed: 422.78 samples/sec	accuracy=0.885010
# INFO:root:Epoch[1] Batch [256]	Speed: 419.86 samples/sec	accuracy=0.911133
# INFO:root:Epoch[1] Batch [320]	Speed: 419.61 samples/sec	accuracy=0.923828
# INFO:root:Epoch[1] Batch [384]	Speed: 418.15 samples/sec	accuracy=0.927490
# INFO:root:Epoch[1] Batch [448]	Speed: 420.16 samples/sec	accuracy=0.922363
# INFO:root:Epoch[1] Batch [512]	Speed: 419.12 samples/sec	accuracy=0.941650
# INFO:root:Epoch[1] Train-accuracy=0.942036
# INFO:root:Epoch[1] Time cost=83.427
# INFO:root:Saved checkpoint to "cnn-mxnet-chkpt-0002.params"
# INFO:root:Epoch[1] Validation-accuracy=0.909647
# INFO:root:Epoch[2] Batch [64]	Speed: 416.48 samples/sec	accuracy=0.946875
# INFO:root:Epoch[2] Batch [128]	Speed: 412.82 samples/sec	accuracy=0.952393
# INFO:root:Epoch[2] Batch [192]	Speed: 411.93 samples/sec	accuracy=0.959961
# INFO:root:Epoch[2] Batch [256]	Speed: 409.05 samples/sec	accuracy=0.954590
# INFO:root:Epoch[2] Batch [320]	Speed: 409.81 samples/sec	accuracy=0.965332
# INFO:root:Epoch[2] Batch [384]	Speed: 398.26 samples/sec	accuracy=0.960205
# INFO:root:Epoch[2] Batch [448]	Speed: 397.39 samples/sec	accuracy=0.970703
# INFO:root:Epoch[2] Batch [512]	Speed: 407.14 samples/sec	accuracy=0.964355
# INFO:root:Epoch[2] Train-accuracy=0.965726
# INFO:root:Epoch[2] Time cost=85.298
# INFO:root:Saved checkpoint to "cnn-mxnet-chkpt-0003.params"
# INFO:root:Epoch[2] Validation-accuracy=0.906703
# INFO:root:Epoch[3] Batch [64]	Speed: 410.92 samples/sec	accuracy=0.968029
# INFO:root:Epoch[3] Batch [128]	Speed: 412.36 samples/sec	accuracy=0.970947
# INFO:root:Epoch[3] Batch [192]	Speed: 411.15 samples/sec	accuracy=0.975342
# INFO:root:Epoch[3] Batch [256]	Speed: 393.63 samples/sec	accuracy=0.965576
# INFO:root:Epoch[3] Batch [320]	Speed: 402.01 samples/sec	accuracy=0.977295
# INFO:root:Epoch[3] Batch [384]	Speed: 399.76 samples/sec	accuracy=0.969727
# INFO:root:Epoch[3] Batch [448]	Speed: 410.37 samples/sec	accuracy=0.971436
# INFO:root:Epoch[3] Batch [512]	Speed: 409.59 samples/sec	accuracy=0.970703
# INFO:root:Epoch[3] Train-accuracy=0.975806
# INFO:root:Epoch[3] Time cost=85.576
# INFO:root:Saved checkpoint to "cnn-mxnet-chkpt-0004.params"
# INFO:root:Epoch[3] Validation-accuracy=0.922101
# INFO:root:Epoch[4] Batch [64]	Speed: 408.97 samples/sec	accuracy=0.975721
# INFO:root:Epoch[4] Batch [128]	Speed: 392.79 samples/sec	accuracy=0.979004
# INFO:root:Epoch[4] Batch [192]	Speed: 407.49 samples/sec	accuracy=0.980713
# INFO:root:Epoch[4] Batch [256]	Speed: 409.55 samples/sec	accuracy=0.978516
# INFO:root:Epoch[4] Batch [320]	Speed: 408.50 samples/sec	accuracy=0.983154
# INFO:root:Epoch[4] Batch [384]	Speed: 411.39 samples/sec	accuracy=0.977539
# INFO:root:Epoch[4] Batch [448]	Speed: 402.46 samples/sec	accuracy=0.982666
# INFO:root:Epoch[4] Batch [512]	Speed: 392.13 samples/sec	accuracy=0.972656
# INFO:root:Epoch[4] Train-accuracy=0.970262
# INFO:root:Epoch[4] Time cost=86.117
# INFO:root:Saved checkpoint to "cnn-mxnet-chkpt-0005.params"
# INFO:root:Epoch[4] Validation-accuracy=0.920290
# INFO:root:Epoch[5] Batch [64]	Speed: 408.84 samples/sec	accuracy=0.976202
# INFO:root:Epoch[5] Batch [128]	Speed: 410.20 samples/sec	accuracy=0.979492
# INFO:root:Epoch[5] Batch [192]	Speed: 398.18 samples/sec	accuracy=0.983398
# INFO:root:Epoch[5] Batch [256]	Speed: 403.81 samples/sec	accuracy=0.983887
# INFO:root:Epoch[5] Batch [320]	Speed: 407.03 samples/sec	accuracy=0.986084
# INFO:root:Epoch[5] Batch [384]	Speed: 376.75 samples/sec	accuracy=0.984619
# INFO:root:Epoch[5] Batch [448]	Speed: 400.91 samples/sec	accuracy=0.984375
# INFO:root:Epoch[5] Batch [512]	Speed: 393.83 samples/sec	accuracy=0.984131
# INFO:root:Epoch[5] Train-accuracy=0.985383
# INFO:root:Epoch[5] Time cost=86.967
# INFO:root:Saved checkpoint to "cnn-mxnet-chkpt-0006.params"
# INFO:root:Epoch[5] Validation-accuracy=0.909647
# INFO:root:Epoch[6] Batch [64]	Speed: 386.40 samples/sec	accuracy=0.990625
# INFO:root:Epoch[6] Batch [128]	Speed: 401.48 samples/sec	accuracy=0.986572
# INFO:root:Epoch[6] Batch [192]	Speed: 380.23 samples/sec	accuracy=0.976807
# INFO:root:Epoch[6] Batch [256]	Speed: 402.80 samples/sec	accuracy=0.976074
# INFO:root:Epoch[6] Batch [320]	Speed: 400.66 samples/sec	accuracy=0.985596
# INFO:root:Epoch[6] Batch [384]	Speed: 404.72 samples/sec	accuracy=0.980713
# INFO:root:Epoch[6] Batch [448]	Speed: 399.70 samples/sec	accuracy=0.987793
# INFO:root:Epoch[6] Batch [512]	Speed: 386.33 samples/sec	accuracy=0.985840
# INFO:root:Epoch[6] Train-accuracy=0.982863
# INFO:root:Epoch[6] Time cost=87.991
# INFO:root:Saved checkpoint to "cnn-mxnet-chkpt-0007.params"
# INFO:root:Epoch[6] Validation-accuracy=0.907156
# INFO:root:Epoch[7] Batch [64]	Speed: 375.55 samples/sec	accuracy=0.986538
# INFO:root:Epoch[7] Batch [128]	Speed: 398.59 samples/sec	accuracy=0.984131
# INFO:root:Epoch[7] Batch [192]	Speed: 394.12 samples/sec	accuracy=0.979248
# INFO:root:Epoch[7] Batch [256]	Speed: 405.13 samples/sec	accuracy=0.985107
# INFO:root:Epoch[7] Batch [320]	Speed: 393.46 samples/sec	accuracy=0.988037
# INFO:root:Epoch[7] Batch [384]	Speed: 392.04 samples/sec	accuracy=0.983398
# INFO:root:Epoch[7] Batch [448]	Speed: 379.26 samples/sec	accuracy=0.982422
# INFO:root:Epoch[7] Batch [512]	Speed: 385.30 samples/sec	accuracy=0.984131
# INFO:root:Epoch[7] Train-accuracy=0.978831
# INFO:root:Epoch[7] Time cost=89.065
# INFO:root:Saved checkpoint to "cnn-mxnet-chkpt-0008.params"
# INFO:root:Epoch[7] Validation-accuracy=0.907609
# INFO:root:Epoch[8] Batch [64]	Speed: 383.55 samples/sec	accuracy=0.984856
# INFO:root:Epoch[8] Batch [128]	Speed: 384.56 samples/sec	accuracy=0.983643
# INFO:root:Epoch[8] Batch [192]	Speed: 375.57 samples/sec	accuracy=0.983154
# INFO:root:Epoch[8] Batch [256]	Speed: 368.82 samples/sec	accuracy=0.987061
# INFO:root:Epoch[8] Batch [320]	Speed: 378.02 samples/sec	accuracy=0.984619
# INFO:root:Epoch[8] Batch [384]	Speed: 391.16 samples/sec	accuracy=0.989014
# INFO:root:Epoch[8] Batch [448]	Speed: 382.76 samples/sec	accuracy=0.991211
# INFO:root:Epoch[8] Batch [512]	Speed: 372.50 samples/sec	accuracy=0.989746
# INFO:root:Epoch[8] Train-accuracy=0.986895
# INFO:root:Epoch[8] Time cost=91.746
# INFO:root:Saved checkpoint to "cnn-mxnet-chkpt-0009.params"
# INFO:root:Epoch[8] Validation-accuracy=0.897418
# INFO:root:Epoch[9] Batch [64]	Speed: 366.99 samples/sec	accuracy=0.986779
# INFO:root:Epoch[9] Batch [128]	Speed: 371.46 samples/sec	accuracy=0.986572
# INFO:root:Epoch[9] Batch [192]	Speed: 360.45 samples/sec	accuracy=0.989990
# INFO:root:Epoch[9] Batch [256]	Speed: 381.40 samples/sec	accuracy=0.984375
# INFO:root:Epoch[9] Batch [320]	Speed: 375.11 samples/sec	accuracy=0.983643
# INFO:root:Epoch[9] Batch [384]	Speed: 367.68 samples/sec	accuracy=0.987793
# INFO:root:Epoch[9] Batch [448]	Speed: 358.10 samples/sec	accuracy=0.987305
# INFO:root:Epoch[9] Batch [512]	Speed: 361.28 samples/sec	accuracy=0.985107
# INFO:root:Epoch[9] Train-accuracy=0.988911
# INFO:root:Epoch[9] Time cost=94.600
# INFO:root:Saved checkpoint to "cnn-mxnet-chkpt-0010.params"
# INFO:root:Epoch[9] Validation-accuracy=0.934783

# %%
acc = mx.metric.Accuracy()
model.score(val_iter,acc)
print(acc)
# Out:
# EvalMetric: {'accuracy': 0.93478260869565222}

# %%
# Load the model from the checkpoint , we are loading the 10 epoch
sym, arg_params, aux_params = mx.model.load_checkpoint(model_prefix, 10)

# Assign the loaded parameters to the module
mod = mx.mod.Module(symbol=sym, context=mx.cpu(), label_names=None)
mod.bind(for_training=False, data_shapes=[('data', (1,3,32,32))])
mod.set_params(arg_params, aux_params, allow_missing=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os

# define a simple data batch
from collections import namedtuple
Batch = namedtuple('Batch', ['data'])

#load the image , resizes it to 32*32 and converts it to 1*3*32*32 
def get_image(url, show=False):
    img = cv2.imread(url, cv2.IMREAD_COLOR)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    #print ("IMG ", url, img)
   
    if img is None:
         return None
    if show:
        plt.imshow(img)
        plt.axis('off')
        
    # convert into format (batch, RGB, width, height)
    img = cv2.resize(img, (32, 32))
    img = np.swapaxes(img, 0, 2)
    img = np.swapaxes(img, 1, 2) #swaps axis to make it 3*32*32


    img = img[np.newaxis, :] # Add a extra axis to the image so it becomes 1*3*32*32

    return img

def predict(url):
    img = get_image(url, show=True)
    
    # compute the predict probabilities
    mod.forward( Batch([mx.nd.array(img)]) )
#    print ("probs")
#    print (mod.get_outputs()[0].asnumpy())

    probs = mod.get_outputs()[0].asnumpy()
    probs = np.squeeze(probs)
    
    i=0
#    for prob in probs:
#        if prob > .01:
#            print('probability=%10.2f, class=%s' %(prob*100, traffic_labels_dict[i]))
#        i=i+1
        
    # print the top-5
    asp = np.argsort(probs)[::-1]
    for i in asp[0:5]:
        if( probs[i] > 0.01 ):
            print('probability=%7.5f, class=%s' %(probs[i], traffic_labels_dict[i]))

# %%
predict('/usr/local/share/dsLab/datasets/traffic-data/Stop.jpg')
# Out:
# probability=1.00000, class=Stop

# %%
predict('/usr/local/share/dsLab/datasets/traffic-data/turn-left-ahead2.jpg')
# Out:
# probability=1.00000, class=Keep right

# %%
#predict('/usr/local/share/dsLab/datasets/traffic-data/vis.png')
